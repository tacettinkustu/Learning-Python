# %%
import os

# %%
from datetime import datetime

# %%
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
# ...

# %%
print(os.getcwd())
# Out:
# C:\Users\tcttn\Desktop\learning python\Advanced Modules

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Datetime.ipynb', 'Os.ipynb']

# %%
for i in os.listdir():
    print(i)
# Out:
# .ipynb_checkpoints
# Datetime.ipynb
# Os.ipynb

# %%
os.mkdir("try1")

# %%
for i in os.listdir():
    print(i)
# Out:
# .ipynb_checkpoints
# Datetime.ipynb
# Os.ipynb
# try1

# %%
os.makedirs("try2/try3")

# %%
for i in os.listdir():
    print(i)
# Out:
# .ipynb_checkpoints
# Datetime.ipynb
# Os.ipynb
# try1
# try2

# %%
os.rmdir("try2/try3")

# %%
os.mkdir("try2/try3")

# %%
os.removedirs("try2/try3")

# %%
os.rename("try1","try5")

# %%
print(os.stat("try5"))
# Out:
# os.stat_result(st_mode=16895, st_ino=168040561096272915, st_dev=1051487365, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1602839351, st_mtime=1602838560, st_ctime=1602838560)

# %%
print(os.stat("try5").st_mtime)
# Out:
# 1602838560.2271736

# %%
print(datetime.fromtimestamp(os.stat("try5").st_mtime))
# Out:
# 2020-10-16 11:56:00.227174

# %%
print(os.walk("C:/Users/tcttn/Desktop"))
# Out:
# <generator object walk at 0x000001A833D95580>

# %%
for i in os.walk("C:/Users/tcttn/Desktop"):
    print(i)
# Out:
# ('C:/Users/tcttn/Desktop', ['başvuru', 'dersler', 'ecem', 'filmler', 'itsy', 'javascript exercises', 'kararlar', 'learning python', 'nişan', 'nuptial', 'photoshop project', 'shopping-cart', 'Sifirdan-Ileri-Seviyeye-Python-Programlama-master', 'wedding'], ['Adobe Illustrator.lnk', 'Apple ile devam et.url', 'Atom.lnk', 'code-complete-2nd-edition-v413hav.pdf', 'GitHub Desktop.lnk', 'Internet Download Manager.lnk', 'MongoDBCompassCommunity.lnk', 'Photoshop.lnk', 'Postman.lnk', 'Visual Studio Code.lnk', 'YouTube Music.lnk', 'Zoom.lnk'])
# ('C:/Users/tcttn/Desktop\\başvuru', [], ['ALES-2020.pdf', 'cv.pdf', 'Kimlik.pdf', 'Mezuniyet Belgesi.pdf', 'niyetmektubu.docx', 'niyetmektubu.pdf', 'sivil-foto.pdf', 'Tacettin KÜSTÜ 2.jpg', 'Tacettin KÜSTÜ 21.jpg', 'Tacettin KÜSTÜ.PNG', 'Transkript-sm.pdf', 'Transkript.pdf', 'Transkript_compressed.pdf', 'YDS.pdf', 'yok-ogrenci-belgesi-sorgulama.pdf', 'yuksekogretim-mezun-belgesi-sorgulama.pdf'])
# ...

# %%
for dir_path,dir_name,file_name in os.walk("C:/Users/tcttn/Desktop"):
    print("dir_path : ",dir_path)
    print("dir_name : ",dir_name)
    print("file_name : ",file_name)
    print("***********************************************")
# Out:
# dir_path :  C:/Users/tcttn/Desktop
# dir_name :  ['başvuru', 'dersler', 'ecem', 'filmler', 'itsy', 'javascript exercises', 'kararlar', 'learning python', 'nişan', 'nuptial', 'photoshop project', 'shopping-cart', 'Sifirdan-Ileri-Seviyeye-Python-Programlama-master', 'wedding']
# file_name :  ['Adobe Illustrator.lnk', 'Apple ile devam et.url', 'Atom.lnk', 'code-complete-2nd-edition-v413hav.pdf', 'GitHub Desktop.lnk', 'Internet Download Manager.lnk', 'MongoDBCompassCommunity.lnk', 'Photoshop.lnk', 'Postman.lnk', 'Visual Studio Code.lnk', 'YouTube Music.lnk', 'Zoom.lnk']
# ***********************************************
# dir_path :  C:/Users/tcttn/Desktop\başvuru
# dir_name :  []
# ...
